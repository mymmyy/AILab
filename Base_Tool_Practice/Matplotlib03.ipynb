# %%
import pandas as pd
reviews = pd.read_csv('data/fandango_scores.csv')
cols = ['FILM', 'RT_user_norm', 'IMDB_norm', 'Metacritic_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
norm_reviews = reviews[cols]
print(norm_reviews[:1])
# Out:
#                              FILM  RT_user_norm  IMDB_norm  Metacritic_norm  \
# 0  Avengers: Age of Ultron (2015)           4.3        3.9              3.3
#
#    Fandango_Ratingvalue  Fandango_Stars
# 0                   4.5             5.0

# %%
# 画柱状图
import matplotlib.pyplot as plt
from numpy import arange
num_cols = ['RT_user_norm', 'IMDB_norm', 'Metacritic_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']


bar_heights = norm_reviews.ix[1, num_cols].values
print(bar_heights)
bar_positions = arange(5) + 0.75
print(bar_positions)
fig, ax = plt.subplots()
# help(plt.subplots())
# p3表示柱状宽度
ax.bar(bar_positions, bar_heights, 0.3)
plt.show()
# Out:
# [4.0 3.55 3.35 4.5 5.0]
# [0.75 1.75 2.75 3.75 4.75]
# H:\workInstall\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys

# %%
num_cols = ['RT_user_norm', 'IMDB_norm', 'Metacritic_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
bar_heights = norm_reviews.ix[1, num_cols].values
print(bar_heights)
bar_positions = arange(5) + 0.75
print(bar_positions)
tick_positions = range(1, 6)
fig, ax = plt.subplots()

ax.bar(bar_positions, bar_heights, 0.5)
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation=45)

ax.set_xlabel('Rating Source')
ax.set_ylabel('Average Rating')
ax.set_title('Average User Rationg For Avengers: Age of Ultron(2015)')
plt.show()
# Out:
# [4.0 3.55 3.35 4.5 5.0]
# [0.75 1.75 2.75 3.75 4.75]
# H:\workInstall\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
num_cols = ['RT_user_norm', 'IMDB_norm', 'Metacritic_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
bar_heights = norm_reviews.ix[1, num_cols].values
print(bar_heights)
bar_positions = arange(5) + 0.75
print(bar_positions)
bar_widths = norm_reviews.ix[0, num_cols].values
tick_positions = range(1, 6)
fig, ax = plt.subplots()

ax.barh(bar_positions, bar_widths, 0.5)
ax.set_yticks(tick_positions)
ax.set_yticklabels(num_cols, rotation=45)

ax.set_xlabel('Rating Source')
ax.set_ylabel('Average Rating')
ax.set_title('Average User Rationg For Avengers: Age of Ultron(2015)')
plt.show()
# Out:
# [4.0 3.55 3.35 4.5 5.0]
# [0.75 1.75 2.75 3.75 4.75]
# H:\workInstall\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# H:\workInstall\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# # 散点图

# %%
fig, ax = plt.subplots()
ax.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax.set_xlabel('Fandango')
ax.set_ylabel('Rotten Tomatoes')
plt.show()

# %%
fig = plt.figure(figsize=(5, 10))
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)
ax1.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax1.set_xlabel('Fandango')
ax1.set_ylabel('Rotten Tomatoes')
ax2.scatter(norm_reviews['RT_user_norm'], norm_reviews['Fandango_Ratingvalue'])
ax2.set_xlabel('Rotten Tomatoes')
ax2.set_ylabel('Fandango')
plt.show()
